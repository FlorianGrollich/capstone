# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class TrackNetV2Encoder(nn.Module):
    def __init__(self):
        super(TrackNetV2Encoder, self).__init__()
        # Encoder layers (VGG-16 inspired)
        self.conv1 = nn.Sequential(
            nn.Conv2d(9, 64, 3, padding=1),  # 3 frames * 3 channels = 9 input channels
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)  # Downsample to H/2, W/2
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)  # Downsample to H/4, W/4
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(128, 256, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)  # Downsample to H/8, W/8
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(256, 512, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)  # Downsample to H/16, W/16
        )

    def forward(self, x):
        # x: (batch, 9, H, W) - 3 frames stacked
        conv1_out = self.conv1(x)
        conv2_out = self.conv2(conv1_out)
        conv3_out = self.conv3(conv2_out)
        conv4_out = self.conv4(conv3_out)
        return conv4_out, [conv1_out, conv2_out, conv3_out]  # Return bottleneck and skip connections

class TrackNetV2Decoder(nn.Module):
    def __init__(self):
        super(TrackNetV2Decoder, self).__init__()
        # Decoder layers with upsampling and skip connections
        self.up4 = nn.Sequential(
            nn.ConvTranspose2d(512, 256, 4, stride=2, padding=1),
            nn.ReLU()
        )
        self.conv_up4 = nn.Sequential(
            nn.Conv2d(512, 256, 3, padding=1),  # 256 from up4 + 256 from conv3
            nn.ReLU()
        )
        self.up3 = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1),
            nn.ReLU()
        )
        self.conv_up3 = nn.Sequential(
            nn.Conv2d(256, 128, 3, padding=1),  # 128 from up3 + 128 from conv2
            nn.ReLU()
        )
        self.up2 = nn.Sequential(
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),
            nn.ReLU()
        )
        self.conv_up2 = nn.Sequential(
            nn.Conv2d(128, 64, 3, padding=1),  # 64 from up2 + 64 from conv1
            nn.ReLU()
        )
        self.final = nn.Sequential(
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 3, 1)  # Output 3 heatmaps (one per frame)
        )

    def forward(self, x, skip_connections):
        # x: (batch, 512, H/16, W/16), skip_connections: [conv1, conv2, conv3]
        x = self.up4(x)
        x = torch.cat([x, skip_connections[2]], dim=1)  # Concat with conv3
        x = self.conv_up4(x)
        
        x = self.up3(x)
        x = torch.cat([x, skip_connections[1]], dim=1)  # Concat with conv2
        x = self.conv_up3(x)
        
        x = self.up2(x)
        x = torch.cat([x, skip_connections[0]], dim=1)  # Concat with conv1
        x = self.conv_up2(x)
        
        x = self.final(x)  # (batch, 3, H, W) - 3 heatmaps
        return x

# %%
class TrackNetV4(nn.Module):
    def __init__(self, theta_init=0.5):
        super(TrackNetV4, self).__init__()
        self.encoder = TrackNetV2Encoder()
        self.decoder = TrackNetV2Decoder()
        # Learnable parameter for power normalization
        self.theta = nn.Parameter(torch.tensor(theta_init, dtype=torch.float32))

    def generate_motion_attention_maps(self, frames):
        # frames: (batch, 9, H, W) -> split into 3 frames: (batch, 3, H, W) each
        batch_size, _, h, w = frames.shape
        frame1 = frames[:, 0:3, :, :]
        frame2 = frames[:, 3:6, :, :]
        frame3 = frames[:, 6:9, :, :]
        
        # Convert to grayscale (mean across channels)
        gray1 = frame1.mean(dim=1, keepdim=True)  # (batch, 1, H, W)
        gray2 = frame2.mean(dim=1, keepdim=True)
        gray3 = frame3.mean(dim=1, keepdim=True)
        
        # Compute absolute frame differences
        diff1 = torch.abs(gray2 - gray1)  # (batch, 1, H, W)
        diff2 = torch.abs(gray3 - gray2)
        
        # Power normalization with learnable theta
        motion_maps = torch.cat([diff1, diff2], dim=1)  # (batch, 2, H, W)
        motion_maps = torch.pow(motion_maps, self.theta)
        motion_maps = (motion_maps - motion_maps.min()) / (motion_maps.max() - motion_maps.min() + 1e-6)
        
        return motion_maps  # (batch, 2, H, W) - 2 motion maps

    def forward(self, x):
        # x: (batch, 9, H, W) - 3 frames stacked
        # Step 1: Generate motion attention maps
        motion_maps = self.generate_motion_attention_maps(x)  # (batch, 2, H, W)
        
        # Step 2: Encoder-Decoder to get visual features
        bottleneck, skip_connections = self.encoder(x)
        visual_features = self.decoder(bottleneck, skip_connections)  # (batch, 3, H, W)
        
        # Step 3: Motion-aware fusion
        fused_features = torch.zeros_like(visual_features)
        fused_features[:, 0, :, :] = visual_features[:, 0, :, :]  # First frame unchanged
        fused_features[:, 1, :, :] = visual_features[:, 1, :, :] * motion_maps[:, 0, :, :]  # Second frame
        fused_features[:, 2, :, :] = visual_features[:, 2, :, :] * motion_maps[:, 1, :, :]  # Third frame
        
        # Step 4: Apply Sigmoid to get heatmaps
        heatmaps = torch.sigmoid(fused_features)  # (batch, 3, H, W)
        return heatmaps

# Instantiate the model
model = TrackNetV4().to(device)

# %%
def generate_heatmap(center_x, center_y, h, w, sigma=5):
    x, y = np.meshgrid(np.arange(w), np.arange(h))
    heatmap = np.exp(-((x - center_x) ** 2 + (y - center_y) ** 2) / (2 * sigma ** 2))
    return heatmap / heatmap.max()

def generate_heatmap(center_x, center_y, h, w, sigma=5):
    x, y = np.meshgrid(np.arange(w), np.arange(h))
    heatmap = np.exp(-((x - center_x) ** 2 + (y - center_y) ** 2) / (2 * sigma ** 2))
    return heatmap / heatmap.max()

class TrackNetDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.frame_folders = sorted([f for f in os.listdir(root_dir) if f.startswith('frame')])

    def __len__(self):
        return len(self.frame_folders)

    def __getitem__(self, idx):
        frame_folder = os.path.join(self.root_dir, self.frame_folders[idx])
        images = []
        heatmaps = []
        
        for i in range(3):  # Load 3 consecutive frames (image-0 to image-2)
            subfolder = os.path.join(frame_folder, f'image-{i}')
            img_path = os.path.join(subfolder, 'image.jpg')
            label_path = os.path.join(subfolder, 'label.txt')
            
            # Load image with fallback for missing files
            try:
                img = Image.open(img_path).convert('RGB')
            except FileNotFoundError:
                print(f"Image file {img_path} not found, using blank image")
                img = Image.fromarray(np.zeros((288, 512, 3), dtype=np.uint8))  # Blank RGB image
            if self.transform:
                img = self.transform(img)
            images.append(img)
            
            # Load and process label
            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    label = f.readline().strip().split()
                    if not label:  # Empty file or only whitespace
                        heatmap = np.zeros((288, 512))
                    elif len(label) >= 3:  # Valid YOLO format
                        try:
                            x_center = float(label[1]) * 512  # Denormalize to 512x288
                            y_center = float(label[2]) * 288
                            heatmap = generate_heatmap(x_center, y_center, 288, 512)
                        except (ValueError, IndexError) as e:
                            print(f"Error parsing label file {label_path}: {label}, Error: {e}")
                            heatmap = np.zeros((288, 512))
                    else:
                        print(f"Label file {label_path} has insufficient data: {label}")
                        heatmap = np.zeros((288, 512))
            else:
                print(f"No label file at {label_path}, generating zero heatmap")
                heatmap = np.zeros((288, 512))
            heatmaps.append(torch.tensor(heatmap, dtype=torch.float32))
        
        images = torch.cat(images, dim=0)  # (9, H, W)
        heatmaps = torch.stack(heatmaps, dim=0)  # (3, H, W)
        return images, heatmaps

transform = transforms.Compose([
    transforms.Resize((288, 512)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset = TrackNetDataset(root_dir='dataset', transform=transform)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
def weighted_bce_loss(pred, target, pos_weight=100):
    bce = F.binary_cross_entropy(pred, target, reduction='none')
    weights = target * pos_weight + (1 - target)
    return (bce * weights).mean()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
num_epochs = 50

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for batch_idx, (images, heatmaps) in enumerate(dataloader):
        images, heatmaps = images.to(device), heatmaps.to(device)  # (batch, 9, H, W), (batch, 3, H, W)
        
        pred_heatmaps = model(images)  # (batch, 3, H, W)
        
        loss = weighted_bce_loss(pred_heatmaps, heatmaps)
        total_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if batch_idx % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx}/{len(dataloader)}], Loss: {loss.item():.4f}')
    
    avg_loss = total_loss / len(dataloader)
    print(f'Epoch [{epoch+1}/{num_epochs}] Average Loss: {avg_loss:.4f}')

torch.save(model.state_dict(), 'tracknetv4.pth')
# Out:
# Epoch [1/50], Batch [0/247], Loss: 0.7840
# Image file dataset/frame20/image-0/image.jpg not found, using blank image
# No label file at dataset/frame20/image-0/label.txt, generating zero heatmap
# Image file dataset/frame20/image-1/image.jpg not found, using blank image
# No label file at dataset/frame20/image-1/label.txt, generating zero heatmap
# Image file dataset/frame20/image-2/image.jpg not found, using blank image
# No label file at dataset/frame20/image-2/label.txt, generating zero heatmap
# Epoch [1/50], Batch [10/247], Loss: 0.6421
# Epoch [1/50], Batch [20/247], Loss: 0.5427
# Epoch [1/50], Batch [30/247], Loss: 0.5408
# Epoch [1/50], Batch [40/247], Loss: 0.5513
# Epoch [1/50], Batch [50/247], Loss: 0.5721
# Epoch [1/50], Batch [60/247], Loss: 0.5024
# Epoch [1/50], Batch [70/247], Loss: 0.4577
# Epoch [1/50], Batch [80/247], Loss: 0.4441
# Epoch [1/50], Batch [90/247], Loss: 0.4971
# Epoch [1/50], Batch [100/247], Loss: 0.4680
# Epoch [1/50], Batch [110/247], Loss: 0.4799
# Epoch [1/50], Batch [120/247], Loss: 0.4474
# Epoch [1/50], Batch [130/247], Loss: 0.4391
# Epoch [1/50], Batch [140/247], Loss: 0.4272
# Image file dataset/frame960/image-0/image.jpg not found, using blank image
# No label file at dataset/frame960/image-0/label.txt, generating zero heatmap
# Image file dataset/frame960/image-1/image.jpg not found, using blank image
# No label file at dataset/frame960/image-1/label.txt, generating zero heatmap
# Image file dataset/frame960/image-2/image.jpg not found, using blank image
# No label file at dataset/frame960/image-2/label.txt, generating zero heatmap
# Epoch [1/50], Batch [150/247], Loss: 0.4908
# Epoch [1/50], Batch [160/247], Loss: 0.4610
# Epoch [1/50], Batch [170/247], Loss: 0.4447
# Epoch [1/50], Batch [180/247], Loss: 0.4451
# Image file dataset/frame437/image-0/image.jpg not found, using blank image
# No label file at dataset/frame437/image-0/label.txt, generating zero heatmap
# Epoch [1/50], Batch [190/247], Loss: 0.4258
# Epoch [1/50], Batch [200/247], Loss: 0.4631
# Epoch [1/50], Batch [210/247], Loss: 0.4570
# Epoch [1/50], Batch [220/247], Loss: 0.3883
# Epoch [1/50], Batch [230/247], Loss: 0.4208
# Epoch [1/50], Batch [240/247], Loss: 0.4565
# Epoch [1/50] Average Loss: 0.4856
# Epoch [2/50], Batch [0/247], Loss: 0.4431
# Epoch [2/50], Batch [10/247], Loss: 0.4298
# Epoch [2/50], Batch [20/247], Loss: 0.4105
# Epoch [2/50], Batch [30/247], Loss: 0.4161
# Epoch [2/50], Batch [40/247], Loss: 0.4133
# Epoch [2/50], Batch [50/247], Loss: 0.4074
# Epoch [2/50], Batch [60/247], Loss: 0.4287
# Epoch [2/50], Batch [70/247], Loss: 0.4561
# Epoch [2/50], Batch [80/247], Loss: 0.4188
# Epoch [2/50], Batch [90/247], Loss: 0.4234
# Epoch [2/50], Batch [100/247], Loss: 0.4346
# Epoch [2/50], Batch [110/247], Loss: 0.3907
# Epoch [2/50], Batch [120/247], Loss: 0.4451
# Epoch [2/50], Batch [130/247], Loss: 0.4128
# Epoch [2/50], Batch [140/247], Loss: 0.4841
# Image file dataset/frame437/image-0/image.jpg not found, using blank image
# No label file at dataset/frame437/image-0/label.txt, generating zero heatmap
# Epoch [2/50], Batch [150/247], Loss: 0.4241
# Image file dataset/frame20/image-0/image.jpg not found, using blank image
# No label file at dataset/frame20/image-0/label.txt, generating zero heatmap
# Image file dataset/frame20/image-1/image.jpg not found, using blank image
# No label file at dataset/frame20/image-1/label.txt, generating zero heatmap
# Image file dataset/frame20/image-2/image.jpg not found, using blank image
# No label file at dataset/frame20/image-2/label.txt, generating zero heatmap
# Epoch [2/50], Batch [160/247], Loss: 0.4031
# Epoch [2/50], Batch [170/247], Loss: 0.4242
# Epoch [2/50], Batch [180/247], Loss: 0.4173
# Epoch [2/50], Batch [190/247], Loss: 0.4417
# Epoch [2/50], Batch [200/247], Loss: 0.4062
# Image file dataset/frame960/image-0/image.jpg not found, using blank image
# No label file at dataset/frame960/image-0/label.txt, generating zero heatmap
# Image file dataset/frame960/image-1/image.jpg not found, using blank image
# No label file at dataset/frame960/image-1/label.txt, generating zero heatmap
# Image file dataset/frame960/image-2/image.jpg not found, using blank image
# No label file at dataset/frame960/image-2/label.txt, generating zero heatmap
# Epoch [2/50], Batch [210/247], Loss: 0.4094
# Epoch [2/50], Batch [220/247], Loss: 0.3713
# Epoch [2/50], Batch [230/247], Loss: 0.3971
# Epoch [2/50], Batch [240/247], Loss: 0.4143
# Epoch [2/50] Average Loss: 0.4194
# Epoch [3/50], Batch [0/247], Loss: 0.3384
# Epoch [3/50], Batch [10/247], Loss: 0.4414
# Epoch [3/50], Batch [20/247], Loss: 0.4405
# Epoch [3/50], Batch [30/247], Loss: 0.4050
# Image file dataset/frame437/image-0/image.jpg not found, using blank image
# No label file at dataset/frame437/image-0/label.txt, generating zero heatmap
# Epoch [3/50], Batch [40/247], Loss: 0.4091
# Epoch [3/50], Batch [50/247], Loss: 0.4313
# Image file dataset/frame960/image-0/image.jpg not found, using blank image
# No label file at dataset/frame960/image-0/label.txt, generating zero heatmap
# Image file dataset/frame960/image-1/image.jpg not found, using blank image
# No label file at dataset/frame960/image-1/label.txt, generating zero heatmap
# Image file dataset/frame960/image-2/image.jpg not found, using blank image
# No label file at dataset/frame960/image-2/label.txt, generating zero heatmap
# Epoch [3/50], Batch [60/247], Loss: 0.4025
# Epoch [3/50], Batch [70/247], Loss: 0.3462
# Epoch [3/50], Batch [80/247], Loss: 0.4326
# Epoch [3/50], Batch [90/247], Loss: 0.4132
# Epoch [3/50], Batch [100/247], Loss: 0.4063
# Epoch [3/50], Batch [110/247], Loss: 0.4127
# Epoch [3/50], Batch [120/247], Loss: 0.4116
# Epoch [3/50], Batch [130/247], Loss: 0.3716
# Epoch [3/50], Batch [140/247], Loss: 2.1921
# Epoch [3/50], Batch [150/247], Loss: 0.3809
# Epoch [3/50], Batch [160/247], Loss: 0.4199
# Epoch [3/50], Batch [170/247], Loss: 0.4266
# Epoch [3/50], Batch [180/247], Loss: 0.4285
# Epoch [3/50], Batch [190/247], Loss: 0.4537
# Epoch [3/50], Batch [200/247], Loss: 0.4243
# Epoch [3/50], Batch [210/247], Loss: 0.4306
# Epoch [3/50], Batch [220/247], Loss: 0.4060
# Epoch [3/50], Batch [230/247], Loss: 0.4295
# Image file dataset/frame20/image-0/image.jpg not found, using blank image
# No label file at dataset/frame20/image-0/label.txt, generating zero heatmap
# Image file dataset/frame20/image-1/image.jpg not found, using blank image
# No label file at dataset/frame20/image-1/label.txt, generating zero heatmap
# Image file dataset/frame20/image-2/image.jpg not found, using blank image
# No label file at dataset/frame20/image-2/label.txt, generating zero heatmap
# Epoch [3/50], Batch [240/247], Loss: 0.4120
# Epoch [3/50] Average Loss: 0.4192
# Epoch [4/50], Batch [0/247], Loss: 0.4368
# Epoch [4/50], Batch [10/247], Loss: 0.3888
# Epoch [4/50], Batch [20/247], Loss: 0.3916
# Epoch [4/50], Batch [30/247], Loss: 0.4125
# Epoch [4/50], Batch [40/247], Loss: 0.3903
# Epoch [4/50], Batch [50/247], Loss: 0.3582
# Epoch [4/50], Batch [60/247], Loss: 0.3803
# Epoch [4/50], Batch [70/247], Loss: 0.3854
# Epoch [4/50], Batch [80/247], Loss: 0.5071
# Epoch [4/50], Batch [90/247], Loss: 0.3783
# Epoch [4/50], Batch [100/247], Loss: 0.3828
# Epoch [4/50], Batch [110/247], Loss: 0.4221
# Epoch [4/50], Batch [120/247], Loss: 0.3833
# Image file dataset/frame20/image-0/image.jpg not found, using blank image
# No label file at dataset/frame20/image-0/label.txt, generating zero heatmap
# Image file dataset/frame20/image-1/image.jpg not found, using blank image
# No label file at dataset/frame20/image-1/label.txt, generating zero heatmap
# Image file dataset/frame20/image-2/image.jpg not found, using blank image
# No label file at dataset/frame20/image-2/label.txt, generating zero heatmap
# Epoch [4/50], Batch [130/247], Loss: 0.3688
# Epoch [4/50], Batch [140/247], Loss: 0.3902
# Image file dataset/frame960/image-0/image.jpg not found, using blank image
# No label file at dataset/frame960/image-0/label.txt, generating zero heatmap
# Image file dataset/frame960/image-1/image.jpg not found, using blank image
# No label file at dataset/frame960/image-1/label.txt, generating zero heatmap
# Image file dataset/frame960/image-2/image.jpg not found, using blank image
# No label file at dataset/frame960/image-2/label.txt, generating zero heatmap
# Epoch [4/50], Batch [150/247], Loss: 0.3770
# Epoch [4/50], Batch [160/247], Loss: 0.3517
# Epoch [4/50], Batch [170/247], Loss: 0.3950
# Epoch [4/50], Batch [180/247], Loss: 0.3854
# Epoch [4/50], Batch [190/247], Loss: 0.3982
# Epoch [4/50], Batch [200/247], Loss: 0.4202
# Epoch [4/50], Batch [210/247], Loss: 0.4162
# Image file dataset/frame437/image-0/image.jpg not found, using blank image
# No label file at dataset/frame437/image-0/label.txt, generating zero heatmap
# Epoch [4/50], Batch [220/247], Loss: 0.3818
# Epoch [4/50], Batch [230/247], Loss: 0.3879
# Epoch [4/50], Batch [240/247], Loss: 0.4368
# Epoch [4/50] Average Loss: 0.4002
# Epoch [5/50], Batch [0/247], Loss: 0.3878
# Epoch [5/50], Batch [10/247], Loss: 0.4090
# Epoch [5/50], Batch [20/247], Loss: 0.4261
# Epoch [5/50], Batch [30/247], Loss: 0.4010
# Image file dataset/frame437/image-0/image.jpg not found, using blank image
# No label file at dataset/frame437/image-0/label.txt, generating zero heatmap
# Epoch [5/50], Batch [40/247], Loss: 0.3747
# Epoch [5/50], Batch [50/247], Loss: 0.3725
# Epoch [5/50], Batch [60/247], Loss: 0.4164
# Epoch [5/50], Batch [70/247], Loss: 0.3768
# Epoch [5/50], Batch [80/247], Loss: 0.3469
# Image file dataset/frame960/image-0/image.jpg not found, using blank image
# No label file at dataset/frame960/image-0/label.txt, generating zero heatmap
# Image file dataset/frame960/image-1/image.jpg not found, using blank image
# No label file at dataset/frame960/image-1/label.txt, generating zero heatmap
# Image file dataset/frame960/image-2/image.jpg not found, using blank image
# No label file at dataset/frame960/image-2/label.txt, generating zero heatmap
# Epoch [5/50], Batch [90/247], Loss: 0.4124
# Epoch [5/50], Batch [100/247], Loss: 0.4010
# Epoch [5/50], Batch [110/247], Loss: 0.4260
# Epoch [5/50], Batch [120/247], Loss: 0.3501
# Epoch [5/50], Batch [130/247], Loss: 0.4152
# Epoch [5/50], Batch [140/247], Loss: 0.4414
# Epoch [5/50], Batch [150/247], Loss: 0.4604
# Epoch [5/50], Batch [160/247], Loss: 2.7830
# Epoch [5/50], Batch [170/247], Loss: 0.4581
# Epoch [5/50], Batch [180/247], Loss: 0.4225
# Epoch [5/50], Batch [190/247], Loss: 1.5110
# Epoch [5/50], Batch [200/247], Loss: 0.3800
# Image file dataset/frame20/image-0/image.jpg not found, using blank image
# No label file at dataset/frame20/image-0/label.txt, generating zero heatmap
# Image file dataset/frame20/image-1/image.jpg not found, using blank image
# No label file at dataset/frame20/image-1/label.txt, generating zero heatmap
# Image file dataset/frame20/image-2/image.jpg not found, using blank image
# No label file at dataset/frame20/image-2/label.txt, generating zero heatmap
# Epoch [5/50], Batch [210/247], Loss: 0.3855
# Epoch [5/50], Batch [220/247], Loss: 0.4294
# Epoch [5/50], Batch [230/247], Loss: 0.4549
# Epoch [5/50], Batch [240/247], Loss: 0.3786
# Epoch [5/50] Average Loss: 0.4187
# Epoch [6/50], Batch [0/247], Loss: 0.3714
# Epoch [6/50], Batch [10/247], Loss: 0.4136
# Epoch [6/50], Batch [20/247], Loss: 0.4210
# Epoch [6/50], Batch [30/247], Loss: 0.3808
# Epoch [6/50], Batch [40/247], Loss: 0.4062
# Epoch [6/50], Batch [50/247], Loss: 0.4290
# Epoch [6/50], Batch [60/247], Loss: 0.4021
# Epoch [6/50], Batch [70/247], Loss: 0.3415
# Epoch [6/50], Batch [80/247], Loss: 0.3812
# Epoch [6/50], Batch [90/247], Loss: 0.3795
# Epoch [6/50], Batch [100/247], Loss: 0.3702
# Image file dataset/frame960/image-0/image.jpg not found, using blank image
# No label file at dataset/frame960/image-0/label.txt, generating zero heatmap
# Image file dataset/frame960/image-1/image.jpg not found, using blank image
# No label file at dataset/frame960/image-1/label.txt, generating zero heatmap
# Image file dataset/frame960/image-2/image.jpg not found, using blank image
# No label file at dataset/frame960/image-2/label.txt, generating zero heatmap
# Image file dataset/frame437/image-0/image.jpg not found, using blank image
# No label file at dataset/frame437/image-0/label.txt, generating zero heatmap
# Epoch [6/50], Batch [110/247], Loss: 0.4120
# Epoch [6/50], Batch [120/247], Loss: 0.3420
# Epoch [6/50], Batch [130/247], Loss: 0.3794
# Epoch [6/50], Batch [140/247], Loss: 0.3771
# Epoch [6/50], Batch [150/247], Loss: 0.3848
# Epoch [6/50], Batch [160/247], Loss: 0.3448
# Epoch [6/50], Batch [170/247], Loss: 0.4207
# Epoch [6/50], Batch [180/247], Loss: 0.3703
# Epoch [6/50], Batch [190/247], Loss: 0.3575
# Image file dataset/frame20/image-0/image.jpg not found, using blank image
# No label file at dataset/frame20/image-0/label.txt, generating zero heatmap
# Image file dataset/frame20/image-1/image.jpg not found, using blank image
# No label file at dataset/frame20/image-1/label.txt, generating zero heatmap
# Image file dataset/frame20/image-2/image.jpg not found, using blank image
# No label file at dataset/frame20/image-2/label.txt, generating zero heatmap
# Epoch [6/50], Batch [200/247], Loss: 0.3350
# Epoch [6/50], Batch [210/247], Loss: 0.3685
# Epoch [6/50], Batch [220/247], Loss: 0.3658
# Epoch [6/50], Batch [230/247], Loss: 0.3962
# Epoch [6/50], Batch [240/247], Loss: 0.4245
# Epoch [6/50] Average Loss: 0.3912
# Epoch [7/50], Batch [0/247], Loss: 0.5737
# Image file dataset/frame20/image-0/image.jpg not found, using blank image
# No label file at dataset/frame20/image-0/label.txt, generating zero heatmap
# Image file dataset/frame20/image-1/image.jpg not found, using blank image
# No label file at dataset/frame20/image-1/label.txt, generating zero heatmap
# Image file dataset/frame20/image-2/image.jpg not found, using blank image
# No label file at dataset/frame20/image-2/label.txt, generating zero heatmap
# Epoch [7/50], Batch [10/247], Loss: 0.3672
# Epoch [7/50], Batch [20/247], Loss: 0.3778
# Epoch [7/50], Batch [30/247], Loss: 0.4087
# Epoch [7/50], Batch [40/247], Loss: 0.3560
# Epoch [7/50], Batch [50/247], Loss: 0.3806
# Epoch [7/50], Batch [60/247], Loss: 0.4770
# Image file dataset/frame437/image-0/image.jpg not found, using blank image
# No label file at dataset/frame437/image-0/label.txt, generating zero heatmap
# Epoch [7/50], Batch [70/247], Loss: 0.3432
# Epoch [7/50], Batch [80/247], Loss: 0.4017
# Epoch [7/50], Batch [90/247], Loss: 0.3454
# Epoch [7/50], Batch [100/247], Loss: 0.3471
# Epoch [7/50], Batch [110/247], Loss: 0.3723
# Epoch [7/50], Batch [120/247], Loss: 0.3328
# Epoch [7/50], Batch [130/247], Loss: 0.3920
# Epoch [7/50], Batch [140/247], Loss: 0.3930
# Epoch [7/50], Batch [150/247], Loss: 0.3412
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [34,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [36,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [37,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [39,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [43,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [44,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [47,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [48,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [49,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [381,0,0], thread: [3,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [375,0,0], thread: [0,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [375,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [375,0,0], thread: [11,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [375,0,0], thread: [17,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [375,0,0], thread: [18,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [96,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [99,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [101,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [105,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [112,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [113,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [114,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [122,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [17,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [23,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [403,0,0], thread: [26,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [32,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [33,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [36,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [37,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [42,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [43,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [44,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [45,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [46,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [49,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [54,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [375,0,0], thread: [35,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [375,0,0], thread: [56,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [375,0,0], thread: [61,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [1,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [3,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [7,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [9,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [11,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [12,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [14,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [15,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [16,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [23,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [27,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [28,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [353,0,0], thread: [31,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [65,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [72,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [90,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [91,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [347,0,0], thread: [95,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [97,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [101,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [103,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [104,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [107,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [122,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [125,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [101,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [108,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [109,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [110,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [112,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [113,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [114,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [115,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [116,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [118,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [120,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [127,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [381,0,0], thread: [97,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [381,0,0], thread: [101,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [381,0,0], thread: [106,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [381,0,0], thread: [107,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [381,0,0], thread: [116,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [381,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [381,0,0], thread: [123,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [381,0,0], thread: [126,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [67,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [68,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [69,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [71,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [72,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [75,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [76,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [77,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [78,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [79,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [84,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [85,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [86,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [87,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [88,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [89,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [92,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [431,0,0], thread: [93,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [66,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [67,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [69,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [71,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [78,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [79,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [80,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [83,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [84,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [85,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [86,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [87,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [88,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [89,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [94,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [409,0,0], thread: [95,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [37,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [38,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [39,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [42,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [43,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [44,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [46,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [47,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [48,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [51,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [52,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [53,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [54,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [58,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [61,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [62,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [63,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [66,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [68,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [69,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [70,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [71,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [73,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [74,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [75,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [76,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [77,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [80,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [81,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [82,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [83,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [84,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [90,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [91,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [92,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [437,0,0], thread: [95,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [3,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [8,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [9,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [11,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [18,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [22,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [25,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [33,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [36,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [37,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [38,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [39,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [40,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [42,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [43,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [44,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [45,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [47,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [52,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [53,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [54,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [58,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [59,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [425,0,0], thread: [63,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [96,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [127,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [68,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [70,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [71,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [78,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [79,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [80,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [81,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [82,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [83,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [85,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [86,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [92,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [93,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [94,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [95,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [93,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [94,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [369,0,0], thread: [95,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [96,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [97,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [98,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [102,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [107,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [108,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [109,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [110,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [112,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [115,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [397,0,0], thread: [123,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ...
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [65,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [66,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [67,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [68,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [69,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [70,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [71,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [73,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [77,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [81,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [87,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [88,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [89,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [90,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [91,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [92,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [93,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [94,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [39,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [41,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [43,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [44,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [45,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [46,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [48,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [51,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [52,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [53,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [54,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [55,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [58,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [59,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [61,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [448,0,0], thread: [62,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [0,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [1,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [8,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [10,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [11,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [12,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [13,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [14,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [16,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [18,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [19,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [20,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [21,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [27,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [28,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [0,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [1,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [2,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [3,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [5,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [6,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [7,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [9,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [10,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [12,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [13,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [14,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [16,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [17,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [19,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [20,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [21,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [26,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [27,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [466,0,0], thread: [28,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [99,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [104,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [105,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [106,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [107,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [108,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [109,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [110,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [112,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [113,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [117,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [118,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [119,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [120,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [121,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [122,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [123,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [124,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [125,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [126,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [473,0,0], thread: [127,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [100,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [105,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [107,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [111,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [116,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [118,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [119,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [120,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [126,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:94: operator(): block: [463,0,0], thread: [127,0,0] Assertion `input_val >= zero && input_val <= one` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 18
#      15 pred_heatmaps = model(images)  # (batch, 3, H, W)
#      17 loss = weighted_bce_loss(pred_heatmaps, heatmaps)
# ---> 18 total_loss += loss.item()
#      20 optimizer.zero_grad()
#      21 loss.backward()
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
model.eval()
with torch.no_grad():
    sample_images, sample_heatmaps = next(iter(dataloader))
    sample_images = sample_images.to(device)
    pred_heatmaps = model(sample_images)
    
    for i in range(3):
        plt.subplot(2, 3, i+1)
        plt.imshow(sample_images[0, i*3:(i+1)*3].mean(dim=0).cpu(), cmap='gray')
        plt.title(f'Frame {i+1}')
        plt.subplot(2, 3, i+4)
        plt.imshow(pred_heatmaps[0, i].cpu(), cmap='hot')
        plt.title(f'Heatmap {i+1}')
    plt.show()
